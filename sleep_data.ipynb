# %%
from pathlib import Path

import pandas as pd

possible_paths = [
    Path("Project/Group Project/data/sleeptime_prediction_dataset.csv"),
    Path("data/sleeptime_prediction_dataset.csv"),
]

csv_path = next((path for path in possible_paths if path.exists()), None)

if csv_path is None:
    checked_paths = "\n".join(str(path.resolve()) for path in possible_paths)
    raise FileNotFoundError(f"Could not find the dataset. Checked:\n{checked_paths}")

df = pd.read_csv(csv_path)
df.head()
# Out:
#    WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 0         1.12         0.52       3.29       7.89          216.08
# 1         2.85         0.49       4.22       5.03          206.18
# 2         2.20         1.81       4.04       9.23           28.73
# 3         1.80         0.50       1.62       7.68          276.77
# 4         0.47         0.54       1.60       4.94          170.54
#
#    RelaxationTime  SleepTime
# 0            0.75       3.45
# 1            0.67       4.88
# 2            0.35       3.61
# 3            1.21       4.94
# 4            0.95       5.50

# %%
from pathlib import Path
Path.cwd()
# Out:
# PosixPath('/Users/hazel/Desktop/School/Corpus Christi College/Data Science')
